# %%
import os

# %%
project_path = r'D:\UCBerkeley\CourseWork\202001\W251\Homework\Project'
dir_openpose = 'openpose_output'
dir_json_original = 'json_NEW'
dir_json_fake = 'json_inference_test'

# %%
original_file_lst = [f for f in os.listdir(os.path.join(project_path, dir_openpose, dir_json_original))] 

for (i, f) in enumerate(original_file_lst):
    new_file_name = str(i).zfill(12) + '_' + f.split('_')[-1]
    # !copy {os.path.join(project_path, dir_openpose, dir_json_original, f)} {os.path.join(project_path, dir_openpose, dir_json_fake, new_file_name)}
    if i >= 5000:
        break
# Out:
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %%
# Out:
# str
